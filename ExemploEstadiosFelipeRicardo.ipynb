# %% [markdown]
# <a href="https://colab.research.google.com/github/felipericardo93/bancodedadosnaorelacional/blob/main/ExemploEstadiosFelipeRicardo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 35.4 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 14.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
client = MongoClient("mongodb+srv://felipe:123@clusterestadios.r5x5t.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios")

# %%
db = client.get_database('futebol')

# %%
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('67124fcdac0134380123428a'), ObjectId('67124fcdac0134380123428b'), ObjectId('67124fcdac0134380123428c'), ObjectId('67124fcdac0134380123428d'), ObjectId('67124fcdac0134380123428e'), ObjectId('67124fcdac0134380123428f'), ObjectId('67124fcdac01343801234290'), ObjectId('67124fcdac01343801234291'), ObjectId('67124fcdac01343801234292'), ObjectId('67124fcdac01343801234293'), ObjectId('67124fcdac01343801234294'), ObjectId('67124fcdac01343801234295'), ObjectId('67124fcdac01343801234296'), ObjectId('67124fcdac01343801234297'), ObjectId('67124fcdac01343801234298'), ObjectId('67124fcdac01343801234299'), ObjectId('67124fcdac0134380123429a'), ObjectId('67124fcdac0134380123429b'), ObjectId('67124fcdac0134380123429c'), ObjectId('67124fcdac0134380123429d')], acknowledged=True)

# %%
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterestadios-shard-00-00.r5x5t.mongodb.net:27017', 'clusterestadios-shard-00-02.r5x5t.mongodb.net:27017', 'clusterestadios-shard-00-01.r5x5t.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterEstadios', authsource='admin', replicaset='atlas-jde0wr-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('67124f7668f8dae207558085'),
#   'nome': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.57243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('67124fcdac0134380123428a'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('67124fcdac0134380123428b'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('67124fcdac0134380123428c'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('67124fcdac0134380123428d'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('67124fcdac0134380123428e'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('67124fcdac0134380123428f'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('67124fcdac01343801234290'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('67124fcdac01343801234291'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('67124fcdac01343801234292'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('67124fcdac01343801234293'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('67124fcdac01343801234294'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('67124fcdac01343801234295'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('67124fcdac01343801234296'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('67124fcdac01343801234297'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('67124fcdac01343801234298'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('67124fcdac01343801234299'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('67124fcdac0134380123429a'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('67124fcdac0134380123429b'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('67124fcdac0134380123429c'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('67124fcdac0134380123429d'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc(0)

# %%
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width=800, height=600)

# %%
qtde = len

# %%
qtde
# Out:
# <function len(obj, /)>

# %%
# Define qtde como o número de linhas do DataFrame
qtde = df_convertido.shape[0]

for i in range(qtde):
    lng = float(df_convertido.iloc[i]['longitude'])
    lat = float(df_convertido.iloc[i]['latitude'])
    description = 'Estádio: ' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
    folium.Marker([lat, lng],
                  popup=description,
                  icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d2bc82ea2c3ba0922a440cd662d97cd {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d2bc82ea2c3ba0922a440cd662d97cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d2bc82ea2c3ba0922a440cd662d97cd = L.map(
#                 &quot;map_4d2bc82ea2c3ba0922a440cd662d97cd&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8770d1241e6803da375a3e3e79f33d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d8770d1241e6803da375a3e3e79f33d7.addTo(map_4d2bc82ea2c3ba0922a440cd662d97cd);
#
#
#             var marker_6ab6433ba1619c02ce19b684b181319c = L.marker(
#                 [-23.57243, -46.20123],
#                 {}
#             ).addTo(map_4d2bc82ea2c3ba0922a440cd662d97cd);
#
#
#             var icon_75954e0f033bc2a599a2d666ec53c477 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ab6433ba1619c02ce19b684b181319c.setIcon(icon_75954e0f033bc2a599a2d666ec53c477);
#
#
#         var popup_8836fb878413b9c0a41607d75cc6ed0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbf36b0fe4034db03a7b697a183fac24 = $(`&lt;div id=&quot;html_fbf36b0fe4034db03a7b697a183fac24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Vila Belmiro&lt;br&gt; Capacidade: 21732&lt;/div&gt;`)[0];
#                 popup_8836fb878413b9c0a41607d75cc6ed0c.setContent(html_fbf36b0fe4034db03a7b697a183fac24);
#
#
#
#         marker_6ab6433ba1619c02ce19b684b181319c.bindPopup(popup_8836fb878413b9c0a41607d75cc6ed0c)
#         ;
#
#
#
#
#             var marker_1d04847ad07837f4d9869c4fb30fd0de = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_4d2bc82ea2c3ba0922a440cd662d97cd);
#
#
#             var icon_ac8e5fac85da01ddb1e7fc9b171664d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1d04847ad07837f4d9869c4fb30fd0de.setIcon(icon_ac8e5fac85da01ddb1e7fc9b171664d3);
#
#
#         var popup_547392d2079c1aec51a77afcfc10470f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_681f8462fd4d3705c484c54858af18a6 = $(`&lt;div id=&quot;html_681f8462fd4d3705c484c54858af18a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_547392d2079c1aec51a77afcfc10470f.setContent(html_681f8462fd4d3705c484c54858af18a6);
#
#
#
#         marker_1d04847ad07837f4d9869c4fb30fd0de.bindPopup(popup_547392d2079c1aec51a77afcfc10470f)
#         ;
#
#
#
#
#             var marker_addcd24d1d8fc2b111329d2a1ff4a4a7 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_4d2bc82ea2c3ba0922a440cd662d97cd);
#
#
#             var icon_0ec8ffada183cb06547a30761523f162 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_addcd24d1d8fc2b111329d2a1ff4a4a7.setIcon(icon_0ec8ffada183cb06547a30761523f162);
#
#
#         var popup_3d230cc40b15c243133baca06fdc38fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5eee314647202738a254c9c2f83af97 = $(`&lt;div id=&quot;html_b5eee314647202738a254c9c2f83af97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_3d230cc40b15c243133baca06fdc38fc.setContent(html_b5eee314647202738a254c9c2f83af97);
#
#
#
#         marker_addcd24d1d8fc2b111329d2a1ff4a4a7.bindPopup(popup_3d230cc40b15c243133baca06fdc38fc)
#         ;
#
#
#
#
#             var marker_64c94716ca7bc1842a0e5b2ad43b5e21 = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_4d2bc82ea2c3ba0922a440cd662d97cd);
#
#
#             var icon_f96267e05c8ae1f04ff4272de33d5c91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-
